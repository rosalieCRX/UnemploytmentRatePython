# %% [markdown]
# <a href="https://colab.research.google.com/github/rosalieCRX/UnemploytmentRatePython/blob/main/plot_all_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(20,6))
df.plot(ax = axes[0],figsize=(20,6)) 
df[int(len(df)*0.6):].plot(ax = axes[1],figsize=(20,6))

fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(20,6))
df.plot(ax = axes[0],figsize=(8,6),subplots=True, layout=(3,4)) 
df[int(len(df)*0.6):].plot(ax = axes[1],figsize=(8,6),subplots=True, layout=(3,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a8b1494ca139> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(20,6))
# ----> 3 df.plot(ax = axes[0],figsize=(20,6))
#       4 df[floor(len(df)*0.6):].plot(ax = axes[1],figsize=(20,6))
#       5
#
# NameError: name 'df' is not defined
