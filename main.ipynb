# %% [markdown]
# <a href="https://colab.research.google.com/github/rosalieCRX/UnemploytmentRatePython/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Get dataframe df:
#
# Unemployment Rate, Initial Claims, 3-Month Treasury Bill, 5 Year Yield, 10 Year Yield, 1 Year Yield, Baa Yield, Aaa Yield, Effective Federal Funds Rate, CLI, Housing Starts

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/formatData.ipynb"
# Out:
# ...
# >>> process series:
#
# UNRATENSA series processded
# ICSA series processded
# TB3MS series processded
# GS5 series processded
# GS10 series processded
# GS1 series processded
# BAA series processded
# AAA series processded
# FEDFUNDS series processded
# USALOLITONOSTSAM series processded
# HOUST series processded
#
# >>> view series:
#              Unemployment Rate  Initial Claims  ...        CLI  Housing Starts
# Date                                           ...
# 1919-01-31                NaN             NaN  ...        NaN             NaN
# 1919-02-28                NaN             NaN  ...        NaN             NaN
# 1919-03-31                NaN             NaN  ...        NaN             NaN
# 1919-04-30                NaN             NaN  ...        NaN             NaN
# 1919-05-31                NaN             NaN  ...        NaN             NaN
# ...                       ...             ...  ...        ...             ...
# ...

# %% [markdown]
# 2. Check and resolve stationarity of each series
#
# why would series with seasonality be stationary?

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/analyze stationarity.ipynb"
# Out:
# >>> Unemployment Rate:
#
# ADF Statistic: -3.8288, MacKinnon p-value: 0.0026
# n_lags: 15
# Critial Values: < 1%
#
#
# >>> Initial Claims:
#
# ADF Statistic: -9.7125, MacKinnon p-value: 0.0
# n_lags: 2
# Critial Values: < 1%
#
#
# >>> 3-Month Treasury Bill:
#
# ADF Statistic: -2.0074, MacKinnon p-value: 0.2833
# n_lags: 21
# Critial Values: > 10%
#
#
# >>> 5 Year Yield:
#
# ADF Statistic: -1.0407, MacKinnon p-value: 0.7381
# n_lags: 21
# Critial Values: > 10%
#
#
# >>> 10 Year Yield:
#
# ADF Statistic: -0.8797, MacKinnon p-value: 0.7946
# n_lags: 21
# Critial Values: > 10%
#
#
# >>> 1 Year Yield:
#
# ADF Statistic: -1.7955, MacKinnon p-value: 0.3827
# n_lags: 20
# Critial Values: > 10%
#
#
# >>> Baa Yield:
#
# ADF Statistic: -1.6366, MacKinnon p-value: 0.464
# n_lags: 16
# Critial Values: > 10%
#
#
# >>> Aaa Yield:
#
# ADF Statistic: -1.0949, MacKinnon p-value: 0.7171
# n_lags: 23
# Critial Values: > 10%
#
#
# >>> Effective Federal Funds Rate:
#
# ...

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/integration.ipynb"
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/analyze stationarity.ipynb"
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/plot all series.ipynb"
# Out:
# 3-Month Treasury Bill, 5 Year Yield, 10 Year Yield, 1 Year Yield, Baa Yield, Aaa Yield dropped and
#  added 1 year spread, 5 year spread, 10 year spread, Corporate Spread
# >>> Unemployment Rate:
#
# ADF Statistic: -3.8288, MacKinnon p-value: 0.0026
# n_lags: 15
# Critial Values: < 1%
#
#
# >>> Initial Claims:
#
# ADF Statistic: -9.7125, MacKinnon p-value: 0.0
# n_lags: 2
# Critial Values: < 1%
#
#
# >>> Effective Federal Funds Rate:
#
# ADF Statistic: -2.6583, MacKinnon p-value: 0.0815
# n_lags: 17
# Critial Values: 5% < and < 10%
#
#
# >>> CLI:
#
# ADF Statistic: -6.9131, MacKinnon p-value: 0.0
# n_lags: 5
# Critial Values: < 1%
#
#
# >>> Housing Starts:
#
# ADF Statistic: -3.7298, MacKinnon p-value: 0.0037
# n_lags: 15
# Critial Values: < 1%
#
#
# >>> 1 year spread:
#
# ADF Statistic: -2.5909, MacKinnon p-value: 0.0949
# n_lags: 21
# Critial Values: 5% < and < 10%
#
#
# >>> 5 year spread:
#
# ADF Statistic: -4.2233, MacKinnon p-value: 0.0006
# n_lags: 20
# Critial Values: < 1%
#
# ...

# %% [markdown]
# 3. ADL model--lag selection
#
#
# ***Problem: which type of robust standard error to choose????***

# %%
# %run "/content/drive/MyDrive/Colab Notebooks/unemployment rate/ADL.ipynb"
# Out:
# >>> seasonality added
# >>> Selecting # of lags for dependent variable:
#
# Unemployment Rate                  AIC: 892.03      # of Lags: 10
#
#
# >>> Selecting # of lags for leading indicators:
#
# Initial Claims                     AIC: -153.24     # of Lags: 5
# CLI                                AIC: 741.75      # of Lags: 3
# Corporate Spread                   AIC: 854.46      # of Lags: 2
# Housing Starts                     AIC: 877.05      # of Lags: 3
# Effective Federal Funds Rate       AIC: 880.57      # of Lags: 4
# 10 year spread                     AIC: 889.41      # of Lags: 7
# Unemployment Rate                  AIC: 892.03      # of Lags: 10
# 5 year spread                      AIC: 892.9       # of Lags: 7
# 1 year spread                      AIC: 893.8       # of Lags: 1
#
#
# >>> Use several leading indicators:
#             lag 1-CS  lag 2-CS  lag 1-CLI  ...  OCTOBER  NOVEMBER  DECEMBER
# Date                                       ...
# ...

# %% [markdown]
# 4. Forecasting with good models
